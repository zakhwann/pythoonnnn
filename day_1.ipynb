# %% [markdown]
# <a href="https://colab.research.google.com/github/zakhwann/pythoonnnn/blob/main/day_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Halo Semester 4!")
# Out:
# Halo Semester 4!

# %%
nama_mahasiswa = "Zakhwan"
umur = 20
ipk = 4.0
status_aktif = True
print(nama_mahasiswa)
print(ipk)
# Out:
# Zakhwan
# 4.0

# %%
matkul_semester = ["Mobile Lanjut", "Data Testing", "Visualisasi"]
print(matkul_semester[0])
matkul_semester.append("Bahasa Inggris")
print(matkul_semester)
# Out:
# Mobile Lanjut
# ['Mobile Lanjut', 'Data Testing', 'Visualisasi', 'Bahasa Inggris']

# %%
data_mahasiswa = {
    "nama" : "Zakhwan",
    "NIM" : "607012400062",
    "Jurusan" : "Sistem Informasi"
}
print(data_mahasiswa["nama"])
# Out:
# Zakhwan

# %%
nama = "Muhammad Zakhwan Abbyasa"
target_ipk = 4.0
skill_saat_ini = ["Laravel", "Flutter"]
skill_saat_ini.append("Python")

if target_ipk >= 3.5 :
    print("Wah, kamu calon mahasiswa Cumlaude!")
    print("Pertahankan Prestasinya")
else :
    print("Yang penting lulus tepat waktu")

print("Daftar Skill yang Ingin Dipelajari: ")
for s in skill_saat_ini :
    print(f"- Menguasai {s}")
# Out:
# Wah, kamu calon mahasiswa Cumlaude!
# Pertahankan Prestasinya
# Daftar Skill yang Ingin Dipelajari:
# - Menguasai Laravel
# - Menguasai Flutter
# - Menguasai Python

# %%
def hitung_nilai_akhir(tugas, uts, uas):
  total = (tugas * 0.3) + (uts * 0.3) + (uas * 0.4)
  return total

nilai_akhir = hitung_nilai_akhir(80,75,90)
print(f"Nilai Akhir Zakhwan {nilai_akhir}")
# Out:
# Nilai Akhir Zakhwan 82.5

# %%
def cek_status_semester(semester):
  if semester < 4:
    return "Masih Dasar"
  elif semester == 4:
    return "Masa Kritis dan Berat"
  else:
    return "Senior"

semester_saya = cek_status_semester(4)
print(semester_saya)
# Out:
# Masa Kritis dan Berat
